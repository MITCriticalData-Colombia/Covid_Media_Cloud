# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %% [markdown]
# # Read data

# %% [markdown]
# ## COVID Cases in Colombia

# %%
covid_cases = pd.read_csv('Covid_Cases_Colombia/output_datasets/daily_covid_cases_in_Colombia.csv')
covid_cases['epiweek'] = pd.to_datetime(covid_cases['epiweek'])
covid_cases = covid_cases.rename(columns={'epiweek':'date'})
covid_cases
# Out:
#           date  Cases
# 0   2020-03-02    1.0
# 1   2020-03-03    1.0
# 2   2020-03-04    0.0
# 3   2020-03-05    0.0
# 4   2020-03-06    1.0
# ..         ...    ...
# 788 2022-04-29  125.0
# 789 2022-04-30   74.0
# 790 2022-05-01   53.0
# 791 2022-05-02   66.0
# 792 2022-05-03    9.0
#
# [793 rows x 2 columns]

# %%
plt.figure(figsize = (12, 8))
plt.plot(covid_cases.date, covid_cases.Cases, color ='blue')
plt.xlabel('Date') 
plt.ylabel('Covid Cases')
plt.show()

# %% [markdown]
# ## COVID Mobility in Colombia

# %%
colombia_mobility = pd.read_csv('Google_Data/Google_Mobility/Mobility_Colombia/mobility_colombia.csv')
colombia_mobility['date'] = pd.to_datetime(colombia_mobility['date'])
colombia_mobility
# Out:
#           date  retail_and_recreation_percent_change_from_baseline  \
# 0   2020-02-15                                          -6.569536
# 1   2020-02-16                                          -5.907801
# 2   2020-02-17                                          -4.377953
# 3   2020-02-18                                          -4.661417
# 4   2020-02-19                                          -5.909091
# ..         ...                                                ...
# 814 2022-05-09                                          16.883333
# 815 2022-05-10                                          20.853448
# 816 2022-05-11                                          19.154472
# 817 2022-05-12                                          24.480000
# 818 2022-05-13                                          22.130769
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                            -2.630252
# 1                                             1.018519
# 2                                             1.136364
# 3                                            -1.623853
# 4                                            -4.467890
# ..                                                 ...
# 814                                          46.515152
# 815                                          51.385417
# 816                                          45.561224
# 817                                          48.031250
# 818                                          44.989796
#
#      parks_percent_change_from_baseline  \
# 0                            -15.682848
# 1                            -14.738854
# 2                             -7.422642
# 3                             -7.338403
# 4                             -8.819853
# ..                                  ...
# 814                           11.991701
# 815                           17.454167
# 816                           16.274590
# 817                           22.159184
# 818                           15.973384
#
#      transit_stations_percent_change_from_baseline  \
# 0                                       -14.753086
# 1                                       -17.493827
# 2                                         2.897436
# 3                                         1.773333
# 4                                         0.435897
# ..                                             ...
# 814                                      30.457143
# 815                                      29.544118
# 816                                      27.800000
# 817                                      30.742857
# 818                                      28.565789
#
#      workplaces_percent_change_from_baseline  \
# 0                                   5.266272
# 1                                  -0.298507
# 2                                  15.296296
# 3                                  16.084656
# 4                                  13.041451
# ..                                       ...
# 814                                48.916996
# 815                                57.861660
# 816                                56.860558
# 817                                55.767717
# 818                                58.471774
#
#      residential_percent_change_from_baseline
# 0                                    1.261682
# 1                                    2.500000
# 2                                   -1.288000
# 3                                   -1.650794
# 4                                   -1.905512
# ..                                        ...
# 814                                  4.833333
# 815                                  3.358621
# 816                                  3.326531
# 817                                  2.609589
# 818                                  3.283688
#
# [819 rows x 7 columns]

# %%
colombia_mobility.dtypes
# Out:
# date                                                  datetime64[ns]
# retail_and_recreation_percent_change_from_baseline           float64
# grocery_and_pharmacy_percent_change_from_baseline            float64
# parks_percent_change_from_baseline                           float64
# transit_stations_percent_change_from_baseline                float64
# workplaces_percent_change_from_baseline                      float64
# residential_percent_change_from_baseline                     float64
# dtype: object

# %%
# Covid cases in time
plt.figure(figsize = (12, 8))
plt.plot(colombia_mobility.index, colombia_mobility['retail_and_recreation_percent_change_from_baseline'], color ='blue', label='retail_and_recreation_percent_change_from_baseline')
plt.plot(colombia_mobility.index, colombia_mobility['grocery_and_pharmacy_percent_change_from_baseline'], color ='red', label='grocery_and_pharmacy_percent_change_from_baseline')
plt.plot(colombia_mobility.index, colombia_mobility['workplaces_percent_change_from_baseline'], color ='green', label='workplaces_percent_change_from_baseline')
plt.plot(colombia_mobility.index, colombia_mobility['residential_percent_change_from_baseline'], color ='black', label='residential_percent_change_from_baseline')
plt.xlabel('date of mobility score in Colombia') 
plt.ylabel('Mobility score')
plt.legend()

# %% [markdown]
# ## Merge Dataframes

# %%
colombia_df = colombia_mobility.merge(covid_cases, how='inner', on="date")
colombia_df.set_index('date', inplace=True)
colombia_df
# Out:
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-03-02                                          -2.362205
# 2020-03-03                                          -3.480000
# 2020-03-04                                          -3.189394
# 2020-03-05                                          -3.046154
# 2020-03-06                                          -3.978102
# ...                                                       ...
# 2022-04-29                                          28.734375
# 2022-04-30                                          32.681159
# 2022-05-01                                          33.223022
# 2022-05-02                                          28.404959
# 2022-05-03                                          26.239316
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-03-02                                           6.216216
# 2020-03-03                                           2.555556
# 2020-03-04                                           1.490741
# 2020-03-05                                           1.570093
# 2020-03-06                                          -0.607143
# ...                                                       ...
# 2022-04-29                                          54.346939
# 2022-04-30                                          60.704762
# 2022-05-01                                          63.901099
# 2022-05-02                                          65.510417
# 2022-05-03                                          60.610526
#
#             parks_percent_change_from_baseline  \
# date
# 2020-03-02                           -7.699248
# 2020-03-03                           -8.198529
# 2020-03-04                           -6.159259
# 2020-03-05                           -5.978182
# 2020-03-06                           -9.683502
# ...                                        ...
# 2022-04-29                           22.787645
# 2022-04-30                           29.571942
# 2022-05-01                           32.505226
# 2022-05-02                           27.982906
# 2022-05-03                           26.995726
#
#             transit_stations_percent_change_from_baseline  \
# date
# 2020-03-02                                       1.615385
# 2020-03-03                                      -0.320513
# 2020-03-04                                      -1.531646
# 2020-03-05                                      -0.435897
# 2020-03-06                                       0.132530
# ...                                                   ...
# 2022-04-29                                      27.844156
# 2022-04-30                                      39.256757
# 2022-05-01                                      36.794521
# 2022-05-02                                      38.142857
# 2022-05-03                                      28.623188
#
#             workplaces_percent_change_from_baseline  \
# date
# 2020-03-02                                17.797872
# 2020-03-03                                18.291005
# 2020-03-04                                16.036082
# 2020-03-05                                15.796875
# 2020-03-06                                22.229508
# ...                                             ...
# 2022-04-29                                64.234568
# 2022-04-30                                49.647321
# 2022-05-01                                37.321244
# 2022-05-02                                58.008230
# 2022-05-03                                60.027778
#
#             residential_percent_change_from_baseline  Cases
# date
# 2020-03-02                                 -1.825397    1.0
# 2020-03-03                                 -1.881890    1.0
# 2020-03-04                                 -2.007692    0.0
# 2020-03-05                                 -1.938462    0.0
# 2020-03-06                                 -2.256000    1.0
# ...                                              ...    ...
# 2022-04-29                                  2.295775  125.0
# 2022-04-30                                  1.646154   74.0
# 2022-05-01                                  2.532110   53.0
# 2022-05-02                                  2.826389   66.0
# 2022-05-03                                  2.650685    9.0
#
# [793 rows x 7 columns]

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Prepare data to supervised learning time series
#
# we will use:
#
# * data: is the dataframe in our case (Covid Cases and Google Mobile Data)
# * n_in: is the number of lag weeks in the past (length of window)
#
# The heart of this "series_to_supervised" function is the <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html">shift</a> fuction of pandas
#
# This function gets as input the number of periods(in this case the number of days represented as rows up or down in the dataframe) to move the columns of a dataframe. E.g.
#
# If we have df.shift(1) all the rows of column cases_medellin will move one row down
# If we have df.shift(-1) all the rows of column cases_medellin will move one row up

# %%
# prepare data for lstm

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# ## normalize features
# As we are working with a Neural Network the data values ​​must be normalized to help backpropagation algorithm So we will use the <a href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html">MinMaxScaler</a> from sklearn

# %%
x = colombia_df.iloc[:,:-1]
y = colombia_df.iloc[:,-1]

# %%
y = np.expand_dims(y.to_numpy(),axis=1)

# %%
scaler_x = MinMaxScaler(feature_range=(0, 1)) # Scaler between 0 and 1
#scaler_y = MinMaxScaler(feature_range=(0, 1)) # Scaler between 0 and 1

# %%
scaled_x = scaler_x.fit_transform(x)
#scaled_y = scaler_y.fit_transform(y)

# %%
scaled = np.concatenate([scaled_x, y], axis=1)

# %%
# length of window
days = 10

# frame as supervised learning
data = series_to_supervised(scaled, n_in=days)
DataFrame(data)
# Out:
#      var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)  var5(t-10)  var6(t-10)  \
# 10     0.545480    0.419901    0.464994    0.612165    0.668078    0.033621
# 11     0.538404    0.401380    0.461680    0.598666    0.671563    0.032300
# 12     0.540244    0.395992    0.475214    0.590221    0.655628    0.029359
# 13     0.541150    0.396394    0.476416    0.597861    0.653938    0.030978
# 14     0.535252    0.385378    0.451824    0.601825    0.699395    0.023552
# ..          ...         ...         ...         ...         ...         ...
# 788    0.666544    0.623898    0.632282    0.834751    0.926369    0.157428
# 789    0.688895    0.628698    0.641560    0.814641    0.924765    0.156299
# 790    0.704017    0.626245    0.644719    0.798338    0.925820    0.156299
# 791    0.682640    0.606658    0.607491    0.784697    0.989313    0.155749
# 792    0.688378    0.614121    0.642387    0.823003    0.887976    0.154683
#
#      var7(t-10)  var1(t-9)  var2(t-9)  var3(t-9)  ...  var5(t-1)  var6(t-1)  \
# 10          1.0   0.538404   0.401380   0.461680  ...   0.646631   0.046529
# 11          1.0   0.540244   0.395992   0.475214  ...   0.641020   0.054580
# 12          0.0   0.541150   0.396394   0.476416  ...   0.681284   0.052353
# 13          0.0   0.535252   0.385378   0.451824  ...   0.606373   0.099259
# 14          1.0   0.547266   0.399539   0.451571  ...   0.547662   0.158989
# ..          ...        ...        ...        ...  ...        ...        ...
# 788       235.0   0.688895   0.628698   0.641560  ...   0.910477   0.183487
# 789       225.0   0.704017   0.626245   0.644719  ...   0.996226   0.129993
# 790       231.0   0.682640   0.606658   0.607491  ...   0.893145   0.114802
# 791       218.0   0.688378   0.614121   0.642387  ...   0.806041   0.135520
# 792       111.0   0.655820   0.589214   0.621396  ...   0.952227   0.142402
#
#      var7(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 10         8.0  0.507397  0.369347  0.444165  0.562113  0.641020  0.054580
# 11        11.0  0.497543  0.372097  0.419578  0.546732  0.681284  0.052353
# 12        13.0  0.508076  0.399589  0.422857  0.498297  0.606373  0.099259
# 13        20.0  0.470481  0.414450  0.406772  0.456210  0.547662  0.158989
# 14        19.0  0.466248  0.432898  0.400329  0.499571  0.540779  0.180065
# ..         ...       ...       ...       ...       ...       ...       ...
# 788      164.0  0.742306  0.663417  0.667335  0.795060  0.996226  0.129993
# 789      125.0  0.767287  0.695584  0.712362  0.874641  0.893145  0.114802
# 790       74.0  0.770717  0.711756  0.731830  0.857472  0.806041  0.135520
# 791       53.0  0.740221  0.719898  0.701816  0.866874  0.952227  0.142402
# 792       66.0  0.726514  0.695107  0.695264  0.800492  0.966499  0.138293
#
#      var7(t)
# 10      11.0
# 11      13.0
# 12      20.0
# 13      19.0
# 14      29.0
# ..       ...
# 788    125.0
# 789     74.0
# 790     53.0
# 791     66.0
# 792      9.0
#
# [783 rows x 77 columns]

# %% [markdown]
# ### Features Set

# %%
# We define the number of features as 7 (Cases and 6 from google mobility)
n_features = 7

# The features to train the model will be all except the values of the actual week 
# We can't use the temperature and precipitation in week t because whe need to resample a a 3D Array
features_set = DataFrame(data.values[:,:-n_features])
# Convert pandas data frame to np.array to reshape as 3D Array
features_set = features_set.to_numpy()
features_set.shape
# Out:
# (783, 70)

# %% [markdown]
# ### Labels Set

# %%
# We will use Dengue cases in last week 
labels_set = DataFrame(data.values[:,-1])
# Convert pandas data frame to np.array
labels_set = labels_set.to_numpy()
labels_set.shape
# Out:
# (783, 1)

# %% [markdown]
# ## Train Test Split

# %%
# We need a sequence so we can't split randomly
# To divide into Train (90%) and test (10%) to do that we need to know the 90% of the total dataframe
size = features_set.shape[0]
split = int(size*(9/10))

# %% [markdown]
# ### Train

# %%
# We will train with 1st 90% of data and test with last 10%
train_X = features_set[:split] ##90% train
train_y = labels_set[:split]  ##90% train

# %% [markdown]
# ### Test

# %%
test_X = features_set[split:] ##10% test
test_y = labels_set[split:] ##10% test

# %% [markdown]
# ### Reshape to tensor

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], days, n_features))
test_X = test_X.reshape((test_X.shape[0], days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (704, 10, 7) (704, 1) (79, 10, 7) (79, 1)

# %% [markdown]
# # Model
# ## LSTM

# %%
# Set Seed
tf.random.set_seed(0)


# design network
model = Sequential()
model.add(LSTM(120, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(LSTM(240, input_shape=(train_X.shape[1], 120)))
model.add(Dense(60))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# Out:
# Metal device set to: Apple M1
# 2022-05-17 09:03:42.520521: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-17 09:03:42.520615: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 120)           61440
#
#  lstm_1 (LSTM)               (None, 240)               346560
#
#  dense (Dense)               (None, 60)                14460
#
#  dense_1 (Dense)             (None, 1)                 61
#
# =================================================================
# Total params: 422,521
# Trainable params: 422,521
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
# fit network
history = model.fit(train_X, train_y, epochs=150, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/150
# 2022-05-17 09:03:42.907896: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-17 09:03:44.020957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:03:44.209138: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:03:44.266109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:03:44.336383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:03:44.406238: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 - 2s - loss: 8583.3848 - val_loss: 520.3888 - 2s/epoch - 218ms/step
# Epoch 2/150
# 2022-05-17 09:03:44.922222: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:03:44.994107: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:03:45.024078: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 - 0s - loss: 8552.5391 - val_loss: 487.5395 - 178ms/epoch - 18ms/step
# Epoch 3/150
# 10/10 - 0s - loss: 8518.9834 - val_loss: 456.0689 - 163ms/epoch - 16ms/step
# Epoch 4/150
# 10/10 - 0s - loss: 8482.8330 - val_loss: 425.1736 - 167ms/epoch - 17ms/step
# Epoch 5/150
# 10/10 - 0s - loss: 8442.5508 - val_loss: 397.6205 - 149ms/epoch - 15ms/step
# Epoch 6/150
# 10/10 - 0s - loss: 8398.3018 - val_loss: 377.1547 - 165ms/epoch - 17ms/step
# Epoch 7/150
# 10/10 - 0s - loss: 8351.1426 - val_loss: 368.4876 - 164ms/epoch - 16ms/step
# Epoch 8/150
# 10/10 - 0s - loss: 8302.9414 - val_loss: 369.3009 - 164ms/epoch - 16ms/step
# Epoch 9/150
# 10/10 - 0s - loss: 8245.6221 - val_loss: 385.7270 - 166ms/epoch - 17ms/step
# Epoch 10/150
# 10/10 - 0s - loss: 8183.8135 - val_loss: 418.8519 - 174ms/epoch - 17ms/step
# Epoch 11/150
# 10/10 - 0s - loss: 8117.4185 - val_loss: 369.0912 - 171ms/epoch - 17ms/step
# Epoch 12/150
# 10/10 - 0s - loss: 8039.5825 - val_loss: 292.9583 - 160ms/epoch - 16ms/step
# Epoch 13/150
# 10/10 - 0s - loss: 7964.9277 - val_loss: 545.3462 - 162ms/epoch - 16ms/step
# Epoch 14/150
# 10/10 - 0s - loss: 7892.7734 - val_loss: 554.2406 - 167ms/epoch - 17ms/step
# Epoch 15/150
# 10/10 - 0s - loss: 7800.1479 - val_loss: 266.6505 - 156ms/epoch - 16ms/step
# Epoch 16/150
# 10/10 - 0s - loss: 7698.6343 - val_loss: 280.4498 - 166ms/epoch - 17ms/step
# Epoch 17/150
# 10/10 - 0s - loss: 7604.4844 - val_loss: 355.1762 - 174ms/epoch - 17ms/step
# Epoch 18/150
# 10/10 - 0s - loss: 7510.4443 - val_loss: 443.2845 - 174ms/epoch - 17ms/step
# Epoch 19/150
# 10/10 - 0s - loss: 7415.3804 - val_loss: 383.5893 - 172ms/epoch - 17ms/step
# Epoch 20/150
# 10/10 - 0s - loss: 7319.9023 - val_loss: 417.0617 - 161ms/epoch - 16ms/step
# Epoch 21/150
# 10/10 - 0s - loss: 7241.0371 - val_loss: 349.7180 - 158ms/epoch - 16ms/step
# Epoch 22/150
# 10/10 - 0s - loss: 7150.7886 - val_loss: 498.8209 - 167ms/epoch - 17ms/step
# Epoch 23/150
# 10/10 - 0s - loss: 7183.8228 - val_loss: 378.2229 - 160ms/epoch - 16ms/step
# Epoch 24/150
# 10/10 - 0s - loss: 7001.0859 - val_loss: 759.0035 - 165ms/epoch - 17ms/step
# Epoch 25/150
# 10/10 - 0s - loss: 7083.0547 - val_loss: 292.3621 - 163ms/epoch - 16ms/step
# Epoch 26/150
# 10/10 - 0s - loss: 7155.0732 - val_loss: 616.1313 - 153ms/epoch - 15ms/step
# Epoch 27/150
# 10/10 - 0s - loss: 6938.1953 - val_loss: 416.0614 - 158ms/epoch - 16ms/step
# Epoch 28/150
# 10/10 - 0s - loss: 6841.1445 - val_loss: 977.9760 - 174ms/epoch - 17ms/step
# Epoch 29/150
# 10/10 - 0s - loss: 6804.8384 - val_loss: 302.5145 - 174ms/epoch - 17ms/step
# Epoch 30/150
# 10/10 - 0s - loss: 6704.3071 - val_loss: 825.8215 - 178ms/epoch - 18ms/step
# Epoch 31/150
# 10/10 - 0s - loss: 6683.6392 - val_loss: 586.2585 - 169ms/epoch - 17ms/step
# Epoch 32/150
# 10/10 - 0s - loss: 6682.7485 - val_loss: 209.9852 - 161ms/epoch - 16ms/step
# Epoch 33/150
# 10/10 - 0s - loss: 6540.4829 - val_loss: 766.6368 - 150ms/epoch - 15ms/step
# Epoch 34/150
# 10/10 - 0s - loss: 6517.7241 - val_loss: 569.8235 - 167ms/epoch - 17ms/step
# Epoch 35/150
# 10/10 - 0s - loss: 6443.1621 - val_loss: 353.6619 - 165ms/epoch - 17ms/step
# Epoch 36/150
# 10/10 - 0s - loss: 6371.1523 - val_loss: 192.3824 - 170ms/epoch - 17ms/step
# Epoch 37/150
# 10/10 - 0s - loss: 6345.5835 - val_loss: 685.8713 - 164ms/epoch - 16ms/step
# Epoch 38/150
# 10/10 - 0s - loss: 6244.5137 - val_loss: 140.7410 - 164ms/epoch - 16ms/step
# Epoch 39/150
# 10/10 - 0s - loss: 6253.8218 - val_loss: 873.9205 - 157ms/epoch - 16ms/step
# Epoch 40/150
# 10/10 - 0s - loss: 6246.1621 - val_loss: 785.0270 - 163ms/epoch - 16ms/step
# Epoch 41/150
# 10/10 - 0s - loss: 6189.2261 - val_loss: 529.5343 - 166ms/epoch - 17ms/step
# Epoch 42/150
# 10/10 - 0s - loss: 6120.8701 - val_loss: 679.5184 - 169ms/epoch - 17ms/step
# Epoch 43/150
# 10/10 - 0s - loss: 6067.1963 - val_loss: 142.9693 - 166ms/epoch - 17ms/step
# Epoch 44/150
# 10/10 - 0s - loss: 6272.8413 - val_loss: 1427.6021 - 173ms/epoch - 17ms/step
# Epoch 45/150
# 10/10 - 0s - loss: 6067.7383 - val_loss: 1251.9857 - 161ms/epoch - 16ms/step
# Epoch 46/150
# 10/10 - 0s - loss: 6018.4351 - val_loss: 752.6472 - 164ms/epoch - 16ms/step
# Epoch 47/150
# 10/10 - 0s - loss: 5973.0640 - val_loss: 765.5452 - 161ms/epoch - 16ms/step
# Epoch 48/150
# 10/10 - 0s - loss: 5809.3354 - val_loss: 98.4638 - 159ms/epoch - 16ms/step
# Epoch 49/150
# 10/10 - 0s - loss: 6034.5601 - val_loss: 901.5682 - 165ms/epoch - 17ms/step
# Epoch 50/150
# 10/10 - 0s - loss: 5827.3560 - val_loss: 683.7274 - 176ms/epoch - 18ms/step
# Epoch 51/150
# 10/10 - 0s - loss: 5421.3335 - val_loss: 198.4917 - 162ms/epoch - 16ms/step
# Epoch 52/150
# 10/10 - 0s - loss: 5690.4844 - val_loss: 946.5413 - 160ms/epoch - 16ms/step
# Epoch 53/150
# 10/10 - 0s - loss: 5549.4473 - val_loss: 146.4260 - 169ms/epoch - 17ms/step
# Epoch 54/150
# 10/10 - 0s - loss: 5298.7480 - val_loss: 407.2066 - 172ms/epoch - 17ms/step
# Epoch 55/150
# 10/10 - 0s - loss: 5373.1929 - val_loss: 176.4698 - 167ms/epoch - 17ms/step
# Epoch 56/150
# 10/10 - 0s - loss: 6698.3965 - val_loss: 664.0390 - 169ms/epoch - 17ms/step
# Epoch 57/150
# 10/10 - 0s - loss: 5615.0430 - val_loss: 1123.8459 - 177ms/epoch - 18ms/step
# Epoch 58/150
# 10/10 - 0s - loss: 5484.2480 - val_loss: 131.2523 - 164ms/epoch - 16ms/step
# Epoch 59/150
# 10/10 - 0s - loss: 5867.9438 - val_loss: 1164.8962 - 168ms/epoch - 17ms/step
# Epoch 60/150
# 10/10 - 0s - loss: 5413.6382 - val_loss: 428.3961 - 167ms/epoch - 17ms/step
# Epoch 61/150
# 10/10 - 0s - loss: 4932.9790 - val_loss: 402.7109 - 165ms/epoch - 16ms/step
# Epoch 62/150
# 10/10 - 0s - loss: 5160.6470 - val_loss: 261.0538 - 162ms/epoch - 16ms/step
# Epoch 63/150
# 10/10 - 0s - loss: 4864.8325 - val_loss: 560.0627 - 174ms/epoch - 17ms/step
# Epoch 64/150
# 10/10 - 0s - loss: 4851.8442 - val_loss: 386.4262 - 159ms/epoch - 16ms/step
# Epoch 65/150
# 10/10 - 0s - loss: 4862.4756 - val_loss: 369.7815 - 158ms/epoch - 16ms/step
# Epoch 66/150
# 10/10 - 0s - loss: 4641.1670 - val_loss: 170.9293 - 160ms/epoch - 16ms/step
# Epoch 67/150
# 10/10 - 0s - loss: 5314.7124 - val_loss: 1103.6179 - 166ms/epoch - 17ms/step
# Epoch 68/150
# 10/10 - 0s - loss: 4688.6978 - val_loss: 253.4140 - 152ms/epoch - 15ms/step
# Epoch 69/150
# 10/10 - 0s - loss: 4609.6172 - val_loss: 447.6219 - 171ms/epoch - 17ms/step
# Epoch 70/150
# 10/10 - 0s - loss: 4403.2588 - val_loss: 242.1367 - 184ms/epoch - 18ms/step
# Epoch 71/150
# 10/10 - 0s - loss: 4700.9307 - val_loss: 544.9430 - 172ms/epoch - 17ms/step
# Epoch 72/150
# 10/10 - 0s - loss: 4426.0791 - val_loss: 423.5629 - 174ms/epoch - 17ms/step
# Epoch 73/150
# 10/10 - 0s - loss: 4510.5908 - val_loss: 375.2691 - 160ms/epoch - 16ms/step
# Epoch 74/150
# 10/10 - 0s - loss: 4294.4985 - val_loss: 547.3727 - 161ms/epoch - 16ms/step
# Epoch 75/150
# 10/10 - 0s - loss: 4564.9648 - val_loss: 488.2723 - 168ms/epoch - 17ms/step
# Epoch 76/150
# 10/10 - 0s - loss: 4242.2603 - val_loss: 350.2922 - 150ms/epoch - 15ms/step
# Epoch 77/150
# 10/10 - 0s - loss: 4207.6924 - val_loss: 341.3342 - 181ms/epoch - 18ms/step
# Epoch 78/150
# 10/10 - 0s - loss: 4209.6289 - val_loss: 257.0453 - 163ms/epoch - 16ms/step
# Epoch 79/150
# 10/10 - 0s - loss: 4559.4102 - val_loss: 922.6422 - 179ms/epoch - 18ms/step
# Epoch 80/150
# 10/10 - 0s - loss: 4151.8423 - val_loss: 182.0402 - 167ms/epoch - 17ms/step
# Epoch 81/150
# 10/10 - 0s - loss: 4435.4956 - val_loss: 1179.2629 - 165ms/epoch - 17ms/step
# Epoch 82/150
# 10/10 - 0s - loss: 4078.1680 - val_loss: 261.5586 - 159ms/epoch - 16ms/step
# Epoch 83/150
# 10/10 - 0s - loss: 5725.9092 - val_loss: 1264.1091 - 173ms/epoch - 17ms/step
# Epoch 84/150
# 10/10 - 0s - loss: 4388.7617 - val_loss: 311.3047 - 174ms/epoch - 17ms/step
# Epoch 85/150
# 10/10 - 0s - loss: 4139.8125 - val_loss: 296.5291 - 157ms/epoch - 16ms/step
# Epoch 86/150
# 10/10 - 0s - loss: 4039.4724 - val_loss: 258.0688 - 178ms/epoch - 18ms/step
# Epoch 87/150
# 10/10 - 0s - loss: 3935.9937 - val_loss: 459.9322 - 178ms/epoch - 18ms/step
# Epoch 88/150
# 10/10 - 0s - loss: 3931.8730 - val_loss: 206.6639 - 168ms/epoch - 17ms/step
# Epoch 89/150
# 10/10 - 0s - loss: 4339.5923 - val_loss: 584.3552 - 161ms/epoch - 16ms/step
# Epoch 90/150
# 10/10 - 0s - loss: 3852.6777 - val_loss: 299.1121 - 158ms/epoch - 16ms/step
# Epoch 91/150
# 10/10 - 0s - loss: 3859.1699 - val_loss: 389.9799 - 166ms/epoch - 17ms/step
# Epoch 92/150
# 10/10 - 0s - loss: 4447.2197 - val_loss: 598.7579 - 165ms/epoch - 17ms/step
# Epoch 93/150
# 10/10 - 0s - loss: 4427.7104 - val_loss: 982.4615 - 160ms/epoch - 16ms/step
# Epoch 94/150
# 10/10 - 0s - loss: 3854.7656 - val_loss: 617.2032 - 172ms/epoch - 17ms/step
# Epoch 95/150
# 10/10 - 0s - loss: 4139.0654 - val_loss: 418.3273 - 156ms/epoch - 16ms/step
# Epoch 96/150
# 10/10 - 0s - loss: 3887.5879 - val_loss: 813.4704 - 166ms/epoch - 17ms/step
# Epoch 97/150
# 10/10 - 0s - loss: 4177.8887 - val_loss: 545.2415 - 159ms/epoch - 16ms/step
# Epoch 98/150
# 10/10 - 0s - loss: 3924.3904 - val_loss: 299.4426 - 162ms/epoch - 16ms/step
# Epoch 99/150
# 10/10 - 0s - loss: 3878.0410 - val_loss: 296.1346 - 166ms/epoch - 17ms/step
# Epoch 100/150
# 10/10 - 0s - loss: 3750.3098 - val_loss: 283.6035 - 158ms/epoch - 16ms/step
# Epoch 101/150
# 10/10 - 0s - loss: 3962.2195 - val_loss: 455.1859 - 178ms/epoch - 18ms/step
# Epoch 102/150
# 10/10 - 0s - loss: 4388.1836 - val_loss: 281.6531 - 160ms/epoch - 16ms/step
# Epoch 103/150
# 10/10 - 0s - loss: 3787.9199 - val_loss: 802.8768 - 167ms/epoch - 17ms/step
# Epoch 104/150
# 10/10 - 0s - loss: 4017.5903 - val_loss: 412.4568 - 160ms/epoch - 16ms/step
# Epoch 105/150
# 10/10 - 0s - loss: 3742.4553 - val_loss: 632.4019 - 160ms/epoch - 16ms/step
# Epoch 106/150
# 10/10 - 0s - loss: 3859.8062 - val_loss: 187.7728 - 170ms/epoch - 17ms/step
# Epoch 107/150
# 10/10 - 0s - loss: 3832.4597 - val_loss: 239.6115 - 168ms/epoch - 17ms/step
# Epoch 108/150
# 10/10 - 0s - loss: 3955.4543 - val_loss: 1291.2555 - 156ms/epoch - 16ms/step
# Epoch 109/150
# 10/10 - 0s - loss: 4466.4609 - val_loss: 567.8560 - 169ms/epoch - 17ms/step
# Epoch 110/150
# 10/10 - 0s - loss: 5000.2705 - val_loss: 1761.2465 - 163ms/epoch - 16ms/step
# Epoch 111/150
# 10/10 - 0s - loss: 5308.9653 - val_loss: 706.4600 - 168ms/epoch - 17ms/step
# Epoch 112/150
# 10/10 - 0s - loss: 4028.1599 - val_loss: 855.7473 - 158ms/epoch - 16ms/step
# Epoch 113/150
# 10/10 - 0s - loss: 4163.9775 - val_loss: 581.9467 - 165ms/epoch - 17ms/step
# Epoch 114/150
# 10/10 - 0s - loss: 3889.5068 - val_loss: 142.8279 - 165ms/epoch - 16ms/step
# Epoch 115/150
# 10/10 - 0s - loss: 3820.4514 - val_loss: 242.6197 - 164ms/epoch - 16ms/step
# Epoch 116/150
# 10/10 - 0s - loss: 3966.9919 - val_loss: 748.2295 - 159ms/epoch - 16ms/step
# Epoch 117/150
# 10/10 - 0s - loss: 3938.5881 - val_loss: 181.9599 - 153ms/epoch - 15ms/step
# Epoch 118/150
# 10/10 - 0s - loss: 3790.5676 - val_loss: 224.0211 - 168ms/epoch - 17ms/step
# Epoch 119/150
# 10/10 - 0s - loss: 3779.4780 - val_loss: 448.8558 - 164ms/epoch - 16ms/step
# Epoch 120/150
# 10/10 - 0s - loss: 3962.7075 - val_loss: 175.3676 - 176ms/epoch - 18ms/step
# Epoch 121/150
# 10/10 - 0s - loss: 3711.8835 - val_loss: 640.4837 - 157ms/epoch - 16ms/step
# Epoch 122/150
# 10/10 - 0s - loss: 3646.1458 - val_loss: 254.5750 - 157ms/epoch - 16ms/step
# Epoch 123/150
# 10/10 - 0s - loss: 3678.2661 - val_loss: 336.9492 - 155ms/epoch - 16ms/step
# Epoch 124/150
# 10/10 - 0s - loss: 3618.3840 - val_loss: 292.1406 - 168ms/epoch - 17ms/step
# Epoch 125/150
# 10/10 - 0s - loss: 3583.7192 - val_loss: 540.3762 - 165ms/epoch - 17ms/step
# Epoch 126/150
# 10/10 - 0s - loss: 3798.5100 - val_loss: 149.8457 - 170ms/epoch - 17ms/step
# Epoch 127/150
# 10/10 - 0s - loss: 3599.2373 - val_loss: 636.0897 - 172ms/epoch - 17ms/step
# Epoch 128/150
# 10/10 - 0s - loss: 3801.5403 - val_loss: 162.0690 - 160ms/epoch - 16ms/step
# Epoch 129/150
# 10/10 - 0s - loss: 3628.6116 - val_loss: 472.5627 - 156ms/epoch - 16ms/step
# Epoch 130/150
# 10/10 - 0s - loss: 3763.4866 - val_loss: 235.1463 - 172ms/epoch - 17ms/step
# Epoch 131/150
# 10/10 - 0s - loss: 3483.9656 - val_loss: 160.3213 - 164ms/epoch - 16ms/step
# Epoch 132/150
# 10/10 - 0s - loss: 3527.7019 - val_loss: 300.1049 - 162ms/epoch - 16ms/step
# Epoch 133/150
# 10/10 - 0s - loss: 3373.0398 - val_loss: 196.9404 - 175ms/epoch - 18ms/step
# Epoch 134/150
# 10/10 - 0s - loss: 3803.0820 - val_loss: 495.7570 - 171ms/epoch - 17ms/step
# Epoch 135/150
# 10/10 - 0s - loss: 3571.8374 - val_loss: 185.7542 - 170ms/epoch - 17ms/step
# Epoch 136/150
# 10/10 - 0s - loss: 4808.3164 - val_loss: 1865.6260 - 170ms/epoch - 17ms/step
# Epoch 137/150
# 10/10 - 0s - loss: 4634.8828 - val_loss: 262.5105 - 174ms/epoch - 17ms/step
# Epoch 138/150
# 10/10 - 0s - loss: 3511.1777 - val_loss: 501.1495 - 159ms/epoch - 16ms/step
# Epoch 139/150
# 10/10 - 0s - loss: 3596.2800 - val_loss: 540.9379 - 166ms/epoch - 17ms/step
# Epoch 140/150
# 10/10 - 0s - loss: 3775.2292 - val_loss: 143.0444 - 176ms/epoch - 18ms/step
# Epoch 141/150
# 10/10 - 0s - loss: 3582.0359 - val_loss: 586.6373 - 162ms/epoch - 16ms/step
# Epoch 142/150
# 10/10 - 0s - loss: 3842.7319 - val_loss: 300.3116 - 182ms/epoch - 18ms/step
# Epoch 143/150
# 10/10 - 0s - loss: 3682.9980 - val_loss: 784.0925 - 167ms/epoch - 17ms/step
# Epoch 144/150
# 10/10 - 0s - loss: 3946.6523 - val_loss: 365.3955 - 166ms/epoch - 17ms/step
# Epoch 145/150
# 10/10 - 0s - loss: 3404.0559 - val_loss: 306.9487 - 167ms/epoch - 17ms/step
# Epoch 146/150
# 10/10 - 0s - loss: 3619.0911 - val_loss: 156.0019 - 161ms/epoch - 16ms/step
# Epoch 147/150
# 10/10 - 0s - loss: 3533.3123 - val_loss: 403.2179 - 158ms/epoch - 16ms/step
# Epoch 148/150
# 10/10 - 0s - loss: 3623.6758 - val_loss: 219.3447 - 161ms/epoch - 16ms/step
# Epoch 149/150
# 10/10 - 0s - loss: 3307.6272 - val_loss: 265.0174 - 170ms/epoch - 17ms/step
# Epoch 150/150
# 10/10 - 0s - loss: 3318.5781 - val_loss: 280.2760 - 167ms/epoch - 17ms/step

# %%
from matplotlib import pyplot
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validation')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Test

# %%
from math import sqrt
from numpy import concatenate

# make a prediction
yhat = model.predict(test_X)
# Out:
# 2022-05-17 09:04:10.356494: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:04:10.441356: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 09:04:10.472421: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
yhat.shape
# Out:
# (79, 1)

# %%
# Invert scaling for forecast
# Inverse Scaler
inv_yhat = yhat

# invert scaling for actual
# Same process than for predicted data (yhat)
#test_y = test_y.reshape((len(test_y), 1))
inv_y = test_y

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# calculate MAPE
mape = mean_absolute_percentage_error(inv_y, inv_yhat)
print('Test MAPE: %.3f' % mape)
# Out:
# Test MAPE: 67.363

# %%
from sklearn.metrics import  mean_absolute_error

# calculate MAE
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test MAE: %.3f' % mae)
# Out:
# Test MAE: 280.276

# %% [markdown]
# # Plot predicted vs actual dengue cases

# %%
data_predict = inv_yhat  ## predicted target  cases
dataY_plot = inv_y  ##  real test-target cases

data_predict = data_predict.reshape(len(data_predict), 1)
dataY_plot = dataY_plot.reshape(len(dataY_plot), 1)

plt.plot(dataY_plot, label = 'actual')
plt.plot(data_predict, label = 'predicted')
plt.legend(loc="upper left")

plt.suptitle('Time-Series Prediction')
plt.show()
