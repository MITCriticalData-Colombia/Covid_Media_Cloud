# %%
#!pip install pytrends

# %% [markdown]
# # Connecting to Google

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
# Source: multiTimeline.csv
col_trends = pd.read_csv('Google_Trends/multiTimeline.csv', skiprows=1)
# Out:
#          Semana  tos: (Colombia)  fiebre: (Colombia)  cansado: (Colombia)  \
# 0    2017-05-21               28                  34                    3
# 1    2017-05-28               31                  34                    3
# 2    2017-06-04               30                  34                    3
# 3    2017-06-11               27                  30                    3
# 4    2017-06-18               26                  37                    4
# ..          ...              ...                 ...                  ...
# 255  2022-04-10               53                  42                    4
# 256  2022-04-17               40                  34                    3
# 257  2022-04-24               40                  36                    4
# 258  2022-05-01               43                  39                    3
# 259  2022-05-08               44                  42                    3
#
#      diarrea: (Colombia)
# 0                     28
# 1                     23
# 2                     22
# 3                     21
# 4                     24
# ..                   ...
# 255                   41
# 256                   36
# 257                   35
# 258                   33
# 259                   32
#
# [260 rows x 5 columns]
